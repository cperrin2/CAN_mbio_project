# %% [markdown]
# <a href="https://colab.research.google.com/github/cperrin2/CAN_mbio_project/blob/main/mbio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# get current directory
from posix import getcwd
import os

os.getcwd
# Out:
# <function posix.getcwd()>

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/Applied Data Science for Social Impact/CAN_mbio_project')

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Applied Data Science for Social Impact/CAN_mbio_project/data/faostat_crops.csv', encoding='latin1')
# Out:
# <ipython-input-15-8ba2f6cfc5bf>:2: DtypeWarning: Columns (11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92,95,98,101,104,107,110,113,116,119,122,125,128,131,134,137,140,143,146,149,152,155,158,161,164,167,170,173,176,179,182,185,188,191) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Applied Data Science for Social Impact/CAN_mbio_project/data/faostat_crops.csv', encoding='latin1')

# %%
df.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0          2            '004  Afghanistan        221          '01371
# 1          2            '004  Afghanistan        221          '01371
# 2          2            '004  Afghanistan        221          '01371
# 3          2            '004  Afghanistan        711          '01654
# 4          2            '004  Afghanistan        711          '01654
#
#                                                 Item  Element Code  \
# 0                                  Almonds, in shell          5312
# 1                                  Almonds, in shell          5419
# 2                                  Almonds, in shell          5510
# 3  Anise, badian, coriander, cumin, caraway, fenn...          5312
# 4  Anise, badian, coriander, cumin, caraway, fenn...          5419
#
#           Element      Unit  Y1961  ... Y2018N    Y2019  Y2019F Y2019N  \
# 0  Area harvested        ha    NaN  ...    NaN  29203.0       A    NaN
# ...

# %%
df.isnull().sum()
# Out:
# Area Code              0
# Area Code (M49)        0
# Area                   0
# Item Code              0
# Item Code (CPC)        0
#                    ...
# Y2020F              7789
# Y2020N             78029
# Y2021              12616
# Y2021F             12616
# Y2021N             78723
# Length: 192, dtype: int64

# %%
# range of years
years_range = range(1961, 2022)

additional_columns = ['Area', 'Item', 'Unit']

# create columns to read
columns_to_read = [f'Y{year}' for year in years_range] + additional_columns

print(columns_to_read)
# Out:
# ['Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020', 'Y2021', 'Area', 'Item', 'Unit']

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Applied Data Science for Social Impact/CAN_mbio_project/data/faostat_crops.csv', encoding='latin1', usecols=columns_to_read)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79297 entries, 0 to 79296
# Data columns (total 64 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    79297 non-null  object
#  1   Item    79297 non-null  object
#  2   Unit    79297 non-null  object
#  3   Y1961   50015 non-null  float64
#  4   Y1962   50047 non-null  float64
#  5   Y1963   50051 non-null  float64
#  6   Y1964   50087 non-null  float64
#  7   Y1965   50090 non-null  float64
#  8   Y1966   50247 non-null  float64
#  9   Y1967   50285 non-null  float64
#  10  Y1968   50382 non-null  float64
#  11  Y1969   50449 non-null  float64
#  12  Y1970   50559 non-null  float64
#  13  Y1971   50641 non-null  float64
#  14  Y1972   50693 non-null  float64
#  15  Y1973   50727 non-null  float64
#  16  Y1974   50802 non-null  float64
#  17  Y1975   50960 non-null  float64
#  18  Y1976   51053 non-null  float64
#  19  Y1977   51272 non-null  float64
# ...

# %%
df.describe()
# Out:
#               Y1961         Y1962         Y1963         Y1964         Y1965  \
# count  5.001500e+04  5.004700e+04  5.005100e+04  5.008700e+04  5.009000e+04
# mean   1.577002e+06  1.606085e+06  1.633636e+06  1.681971e+06  1.713125e+06
# std    1.659174e+07  1.683757e+07  1.708906e+07  1.760502e+07  1.793704e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.500000e+03  2.543000e+03  2.632225e+03  2.702500e+03  2.790250e+03
# 50%    1.780000e+04  1.816000e+04  1.876900e+04  1.927800e+04  1.993800e+04
# 75%    1.160000e+05  1.183670e+05  1.211595e+05  1.243345e+05  1.260000e+05
# max    1.342848e+09  1.360731e+09  1.369425e+09  1.381680e+09  1.398183e+09
#
#               Y1966         Y1967         Y1968         Y1969         Y1970  \
# count  5.024700e+04  5.028500e+04  5.038200e+04  5.044900e+04  5.055900e+04
# mean   1.750773e+06  1.794414e+06  1.820121e+06  1.825589e+06  1.861246e+06
# ...

# %%
non_countries = {
    'World': 'World',
    'Africa': 'Africa',
    'Middle Africa': 'Middle Africa',
    'Northern Africa': 'Northern Africa',
    'Southern Africa': 'Southern Africa',
    'Western Africa': 'Western Africa',
    'Americas': 'Americas',
    'North America' : 'North America',
    'Central America': 'Central America',
    'South America': 'South America',
    'Asia': 'Asia',
    'Central Asia': 'Central Asia',
    'Eastern Asia': 'Eastern Asia',
    'Southern Asia': 'Southern Asia',
    'South-eastern Asia': 'South-eastern Asia',
    'Western Asia': 'Western Asia',
    'Europe': 'Europe',
    'Eastern Europe': 'Eastern Europe',
    'Northern Europe': 'Northern Europe',
    'Southern Europe': 'Southern Europe',
    'Western Europe': 'Western Europe',
    'Oceania': 'Oceania',
    'Australia and New Zealand': 'Australia and New Zealand',
    'Melanesia' : 'Melanesia',
    'Micronesia': 'Micronesia',
    'Polynesia': 'Polynesia',
    'European Union (27)' : 'European Union',
    'Least Developed Countries': 'Least Developed Countries',
    'Land Locked Developing Countries': 'Land Locked Developing Countries',
    'Small Island Developing States' : 'Small Island Developing States',
}

# %%
food_dict = {
    "Apples": 'Fruit',
    "Apricots": 'Fruit',
    "Avocados": 'Fruit',
    "Bananas": 'Fruit',
    "Blueberries": 'Fruit',
    "Brazil nuts, in shell": "Nut",
    "Cashew nuts, in shell": "Nut",
    "Cashewapple": "Nut",
    "Cherries": 'Fruit',
    "Chestnuts, in shell": "Nut",
    "Dates": 'Fruit',
    "Figs": 'Fruit',
    "Gooseberries": 'Fruit',
    "Grapes": 'Fruit',
    "Kiwi fruit": 'Fruit',
    "Lemons and limes": 'Fruit',
    "Mangoes, guavas and mangosteens": 'Fruit',
    "Melonseed": "Nut",
    "Oranges": 'Fruit',
    "Papayas": 'Fruit',
    "Peaches and nectarines": 'Fruit',
    "Pears": 'Fruit',
    "Pineapples": 'Fruit',
    "Pistachios, in shell": 'Fruit',
    "Plums and sloes": 'Fruit',
    "Pomelos and grapefruits": 'Fruit',
    "Raspberries": 'Fruit',
    "Sour cherries": 'Fruit',
    "Tangerines, mandarins, clementines": 'Fruit',
    "Walnuts, in shell": "Nut",
    "Watermelons": 'Fruit',
    "Artichokes": 'Vegetable',
    "Asparagus": 'Vegetable',
    "Cabbages": 'Vegetable',
    "Carrots and turnips": 'Vegetable',
    "Cauliflowers and broccoli": 'Vegetable',
    "Cucumbers and gherkins": 'Vegetable',
    "Eggplants (aubergines)": 'Vegetable',
    "Garlic": 'Vegetable',
    "Green tea (not fermented), black tea (fermented) and partly fermented tea, in immediate packings of a content not exceeding 3 kg": 'Vegetable',
    "Lettuce and chicory": 'Vegetable',
    "Okra": 'Vegetable',
    "Onions and shallots": 'Vegetable',
    "Peppers (Chillies and peppers, dry, Chillies and peppers, green)": 'Vegetable',
    "Potatoes": 'Vegetable',
    "Pumpkins, squash and gourds": 'Vegetable',
    "Spinach": 'Vegetable',
    "String beans": 'Vegetable',
    "Sweet potatoes": 'Vegetable',
    "Tomatoes": 'Vegetable',
    "Yams": 'Vegetable',
    "Yautia": 'Vegetable',
    "Bambara beans, dry": 'Cereal',
    "Barley": 'Cereal',
    "Beans, dry": 'Cereal',
    "Broad beans and horse beans, dry": 'Cereal',
    "Broad beans and horse beans, green": 'Cereal',
    "Buckwheat": 'Cereal',
    "Cereals n.e.c.": 'Cereal',
    "Chick peas, dry": 'Cereal',
    "Groundnuts, excluding shelled": 'Cereal',
    "Lentils, dry": 'Cereal',
    "Maize (corn)": 'Cereal',
    "Mixed grain": 'Cereal',
    "Millet": 'Cereal',
    "Oats": 'Cereal',
    "Peas, dry": 'Cereal',
    "Peas, green": 'Cereal',
    "Quinoa": 'Cereal',
    "Rice": 'Cereal',
    "Rye": 'Cereal',
    "Sorghum": 'Cereal',
    "Triticale": 'Cereal',
    "Wheat": 'Cereal',
    "Bees": 'Animal Product',
    "Butter and ghee": 'Animal Product',
    "Butter and ghee of sheep milk": 'Animal Product',
    "Butter of buffalo milk": 'Animal Product',
    "Butter of cow milk": 'Animal Product',
    "Buttermilk, dry": 'Animal Product',
    "Cheese from milk of buffalo, fresh or processed": 'Animal Product',
    "Cheese from milk of goats, fresh or processed": 'Animal Product',
    "Cheese from milk of sheep, fresh or processed": 'Animal Product',
    "Cheese from skimmed cow milk": 'Animal Product',
    "Cheese from whole cow milk": 'Animal Product',
    "Cream, fresh": 'Animal Product',
    "Edible offal (buffalo, cattle, goat, pigs, sheep, camels, horses, other domestic camelids, other domestic rodents, pigeons and other birds)": 'Animal Product',
    "Eggs from other birds in shell, fresh, n.e.c.": 'Animal Product',
    "Game meat, fresh, chilled or frozen": 'Animal Product',
    "Meat of different animals (buffalo, camels, cattle, chickens, ducks, geese, goat, mules, other domestic camelids, other domestic rodents, pig, pigeons and other birds, rabbits and hares, sheep, turkeys)": 'Animal Product',
    "Meat, poultry": 'Animal Product',
    "Milk, skim milk, buttermilk, condensed milk, evaporated milk, whole milk powder": 'Animal Product',
    "Tallow": 'Animal Product',
    "Almonds, in shell": "Nut",
    "Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw": "Nut",
    "Asses": "Animal Product",
    "Camels": "Animal Product",
    "Cantaloupes and other melons": "Fruit",
    "Cattle": "Animal Product",
    "Cattle fat, unrendered": "Animal Product",
    "Chickens": "Animal Product",
    "Cotton seed": "Cereal",
    "Cottonseed oil": "Oil",
    "Edible offal of cattle, fresh, chilled or frozen": "Animal Product",
    "Edible offal of goat, fresh, chilled or frozen": "Animal Product",
    "Edible offal of sheep, fresh, chilled or frozen": "Animal Product",
    "Edible offals of camels and other camelids, fresh, chilled or frozen": "Animal Product",
    "Fat of camels": "Animal Product",
    "Goat fat, unrendered": "Animal Product",
    "Goats": "Animal Product",
    "Hen eggs in shell, fresh": "Animal Product",
    "Horses": "Animal Product",
    "Linseed": "Animal Product",
    "Meat of camels, fresh or chilled": "Animal Product",
    "Meat of cattle with the bone, fresh or chilled": "Animal Product",
    "Meat of chickens, fresh or chilled": "Animal Product",
    "Meat of goat, fresh or chilled": "Animal Product",
    "Meat of sheep, fresh or chilled": "Animal Product",
    "Molasses": "Other",
    "Mules and hinnies": "Animal Product",
    "Natural honey": "Animal Product",
    "Oil of linseed": "Oil",
    "Oil of sesame seed": "Oil",
    "Olive oil": "Oil",
    "Olives": "Fruit",
    "Onions and shallots, dry (excluding dehydrated)": "Vegetable",
    "Other berries and fruits of the genus vaccinium n.e.c.": "Fruit",
    "Other citrus fruit, n.e.c.": "Fruit",
    "Other fruits, n.e.c.": "Fruit",
    "Other nuts (excluding wild edible nuts and groundnuts), in shell, n.e.c.": "Nut",
    "Other pulses n.e.c.": "Other",
    "Other stimulant, spice and aromatic crops, n.e.c.": "Other",
    "Other stone fruits": "Fruit",
    "Other vegetables, fresh n.e.c.": "Vegetable",
    "Raw cane or beet sugar (centrifugal only)": "Other",
    "Raw hides and skins of cattle": "Animal Product",
    "Raw hides and skins of goats or kids": "Animal Product",
    "Raw hides and skins of sheep or lambs": "Animal Product",
    "Raw milk of camel": "Animal Product",
    "Raw milk of cattle": "Animal Product",
    "Raw milk of goats": "Animal Product",
    "Raw milk of sheep": "Animal Product",
    "Seed cotton, unginned": "Cereal",
    "Sesame seed": "Cereal",
    "Sheep": "Animal Product",
    "Sheep fat, unrendered": "Animal Product",
    "Shorn wool, greasy, including fleece-washed shorn wool": "Animal Product",
    "Skim milk of cows": "Animal Product",
    "Sugar beet": "Other",
    "Sugar cane": "Other",
    "Sunflower seed": "Cereal",
    "Sunflower-seed oil, crude": "Oil",
    "Beef and Buffalo Meat, primary": "Animal Product",
    "Butter and Ghee": "Other",
    "Cattle and Buffaloes": "Animal Product",
    "Cereals, primary": "Cereal",
    "Cheese (All Kinds)": "Other",
    "Citrus Fruit, Total": "Fruit",
    "Eggs Primary": "Animal Product",
    "Fibre Crops, Fibre Equivalent": "Other",
    "Fruit Primary": "Fruit",
    "Meat, Poultry": "Animal Product",
    "Meat, Total": "Animal Product",
    "Milk, Total": "Animal Product",
    "Oilcrops, Cake Equivalent": "Cereal",
    "Oilcrops, Oil Equivalent": "Oil",
    "Poultry Birds": "Animal Product",
    "Pulses, Total": "Other",
    "Roots and Tubers, Total": "Other",
    "Sheep and Goat Meat": "Animal Product",
    "Sheep and Goats": "Animal Product",
    "Skim Milk & Buttermilk, Dry": "Animal Product",
    "Sugar Crops Primary": "Other",
    "Treenuts, Total": "Nut",
    "Vegetables Primary": "Vegetable",
    "Beer of barley, malted": "Other",
    "Beeswax": "Animal Product",
    "Buffalo": "Animal Product",
    "Buffalo fat, unrendered": "Animal Product",
    "Chillies and peppers, green (Capsicum spp. and Pimenta spp.)": "Vegetable",
    "Ducks": "Animal Product",
    "Edible offal of buffalo, fresh, chilled or frozen": "Animal Product",
    "Edible offal of pigs, fresh, chilled or frozen": "Animal Product",
    "Edible offals of horses and other equines,  fresh, chilled or frozen": "Animal Product",
    "Fat of pigs": "Animal Product",
    "Geese": "Other",
    "Green garlic": "Other",
    "Groundnut oil": "Oil",
    "Hop cones": "Other",
    "Horse meat, fresh or chilled": "Animal Product",
    "Leeks and other alliaceous vegetables": "Vegetable",
    "Margarine and shortening": "Other",
    "Meat of asses, fresh or chilled": "Animal Product",
    "Meat of buffalo, fresh or chilled": "Animal Product",
    "Meat of mules, fresh or chilled": "Animal Product",
    "Meat of pig with the bone, fresh or chilled": "Animal Product",
    "Meat of turkeys, fresh or chilled": "Animal Product",
    "Mushrooms and truffles": "Vegetable",
    "Onions and shallots, green": "Vegetable",
    "Other beans, green": "Cereal",
    "Other meat n.e.c. (excluding mammals), fresh, chilled or frozen": "Animal Product",
    "Palm oil": "Oil",
    "Quinces": "Other",
    "Raw hides and skins of buffaloes": "Animal Product",
    "Raw milk of buffalo": "Animal Product",
    "Soya bean oil": "Oil",
    "Soya beans": "Cereal",
    "Strawberries": "Fruit",
    "Swine / pigs": "Animal Product",
    "Turkeys": "Animal Product",
    "Unmanufactured tobacco": "Other",
    "Vetches": "Other",
    "Wine": "Other",
    "Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw": "Fruit",
    "Locust beans (carobs)": "Cereal",
    "Meat of rabbits and hares, fresh or chilled": "Animal Product",
    "Other tropical fruits, n.e.c.": "Fruit",
    "Rabbits and hares": "Animal Product",
    "Rape or colza seed": "Oil Seed",
    "Rapeseed or canola oil, crude": "Oil",
    "Safflower-seed oil, crude": "Oil",
    "Cassava, fresh": "Other",
    "Castor oil seeds": "Cereal",
    "Cocoa beans": "Cereal",
    "Coffee, green": "Other",
    "Flax, processed but not spun": "Cereal",
    "Kenaf, and other textile bast fibres, raw or retted": "Cereal",
    "Oil of palm kernel": "Oil",
    "Oil palm fruit": "Oil",
    "Palm kernels": "Other",
    "Pig fat, rendered": "Animal Product",
    "Sisal, raw": "Cereal",
    "Taro": "Cereal",
    "Canary seed": "Oil",
    "Ghee from cow milk": "Animal Product",
    "Lupins": "Other",
    "Maté leaves": "Other",
    "Meat of ducks, fresh or chilled": "Animal Product",
    "Meat of geese, fresh or chilled": "Animal Product",
    "Oil of maize": "Oil",
    "Other fibre crops, raw, n.e.c.": "Cereal",
    "Other oil seeds, n.e.c.": "Oil",
    "Peppermint, spearmint": "Cereal",
    "Safflower seed": "Cereal",
    "Skim milk and whey powder": "Animal Product",
    "Tea leaves": "Cereal",
    "Tung nuts": "Nut",
    "Whey, dry": "Other",
    "Whole milk powder": "Other",
    "Whole milk, condensed": "Animal Product",
    "Whole milk, evaporated": "Animal Product",
    "Evaporated & Condensed Milk": "Animal Product",
    "Hazelnuts, in shell": "Nut",
    "Coconut oil": "Oil",
    "Cow peas, dry": "Other",
    "Currants": "Other",
    "Green corn (maize)": "Cereal",
    "Mustard seed": "Cereal",
    "Persimmons": "Other",
    "Skim milk, condensed": "Animal Product",
    "Poppy seed": "Cereal",
    "True hemp, raw or retted": "Other",
    "Whey, condensed": "Other",
    "Yoghurt": "Other",
    "Cranberries": "Fruit",
    "Coconuts, in shell": "Nut",
    "Pigeon peas, dry": "Nut",
    "Plantains and cooking bananas": "Fruit",
    "Ghee from buffalo milk": "Animal Product",
    "Ginger, raw": "Cereal",
    "Jute, raw or retted": "Other",
    "Natural rubber in primary forms": "Other",
    "Other sugar crops n.e.c.": "Cereal",
    "Other pome fruits": "Fruit",
    "Chicory roots": "Other",
    "Vanilla, raw": "Other",
    "Edible roots and tubers with high starch or inulin content, n.e.c., fresh": "Other",
    "Fonio": "Other",
    "Karite nuts (sheanuts)": "Nut",
    "Kola nuts": "Nut",
    "Pepper (Piper spp.), raw": "Nut",
    "Nutmeg, mace, cardamoms, raw": "Nut",
    "Meat of other domestic camelids, fresh or chilled": "Animal Product",
    "Meat of other domestic rodents, fresh or chilled": "Animal Product",
    "Other camelids": "Animal Product",
    "Other rodents": "Animal Product",
    "Pyrethrum, dried flowers": "Cereal",
    "Ramie, raw or retted": "Other",
    "Cassava leaves": "Other",
    "Hempseed": "Other",
    "Meat of pigeons and other birds n.e.c., fresh, chilled or frozen": "Animal Product",
    "Skim milk, evaporated": "Animal Product",
    "Cinnamon and cinnamon-tree flowers, raw": "Cereal",
    "Cloves (whole stems), raw": "Cereal",
    "Tallowtree seeds": "Cereal",
    "Agave fibres, raw, n.e.c.": "Other",
    "Abaca, manila hemp, raw": "Other",
    "Snails, fresh, chilled, frozen, dried, salted or in brine, except sea snails": "Animal Product",
    "Kapok fibre, raw": "Other",
    "Kapok fruit": "Fruit",
    "Kapokseed in shell": "Other",
    "Jojoba seeds": "Cereal",
    "Butter of goat milk": "Animal Product",
    "Cotton lint, ginned": "Cereal",
    "Raw silk (not thrown)": "Other",
    "Silk-worm cocoons suitable for reeling": "Animal Product",
    "Areca nuts": "Nut",
    "Coir, raw": "Other",
    "Balata, gutta-percha, guayule, chicle and similar natural gums in primary forms or in plates, sheets or strip": "Other"
}

# %%
# unique values in the "Item" column
unique_items = df['Item'].unique()
print(unique_items)

# if anything not in food_dict
for item in unique_items:
    if item not in food_dict:
        print(f"Item '{item}' not found in food_dict")

# map the "Item" column using the food_dict
df['Food Type'] = df['Item'].map(food_dict)

# map the 'Area' column using non_countries dict
df['Region'] = df['Area'].map(non_countries)

# print(df)
# Out:
# ['Almonds, in shell'
#  'Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw'
#  'Apples' 'Apricots' 'Asses' 'Barley' 'Butter and ghee of sheep milk'
#  'Butter of cow milk' 'Buttermilk, dry' 'Camels'
#  'Cantaloupes and other melons' 'Cattle' 'Cattle fat, unrendered'
#  'Cheese from milk of goats, fresh or processed'
#  'Cheese from milk of sheep, fresh or processed' 'Chickens'
#  'Cotton lint, ginned' 'Cotton seed' 'Cottonseed oil'
#  'Edible offal of cattle, fresh, chilled or frozen'
#  'Edible offal of goat, fresh, chilled or frozen'
#  'Edible offal of sheep, fresh, chilled or frozen'
#  'Edible offals of camels and other camelids, fresh, chilled or frozen'
#  'Fat of camels' 'Figs' 'Game meat, fresh, chilled or frozen'
#  'Goat fat, unrendered' 'Goats' 'Grapes' 'Hen eggs in shell, fresh'
#  'Horses' 'Linseed' 'Maize (corn)' 'Meat of camels, fresh or chilled'
#  'Meat of cattle with the bone, fresh or chilled'
# ...
